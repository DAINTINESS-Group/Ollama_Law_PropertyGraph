# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
#from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
#from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
#from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

## Input data directory
data_dir = "cureus"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Load Documents

# %%
## Dir PDF Loader
# loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
#loader = DirectoryLoader(inputdirectory, show_progress=True)
#documents = loader.load()
#splitter = RecursiveCharacterTextSplitter(
    #chunk_size=1500,
    #chunk_overlap=150,
    #length_function=len,
    #is_separator_regex=False,
#)

#pages = splitter.split_documents(documents)
#print("Number of chunks = ", len(pages))
#print(pages[3].page_content)
import json
from langchain_text_splitters import RecursiveCharacterTextSplitter
import pandas as pd

json_file_path = inputdirectory / "test.json"

with open(json_file_path, "r", encoding="utf-8") as f:
    data = json.load(f)

def extract_text_from_json(json_data):
    text_chunks = []
    
    for chapter in json_data.get("children", []):
        for article in chapter.get("articles", []):
            for paragraph in article.get("paragraphs", []):
                text_content = " ".join(
                    [t["text"].strip() for t in paragraph.get("text", []) if isinstance(t.get("text"), str)]
                )
                text_chunks.append(text_content)

    return text_chunks  

documents = extract_text_from_json(data)

if not documents:
    raise ValueError("No valid text found in the JSON file.")

# Define text splitter
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)


text_content = "\n\n".join(documents) 
pages = splitter.split_text(text_content)

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from langchain.schema import Document
from helpers.df_helpers import documents2Dataframe

documents = [Document(page_content=chunk, metadata={"source": "json"}) for chunk in pages]

df = documents2Dataframe(documents)

print(df.shape)
df.head()
# Out:
# (150, 3)
#                                                 text source  \
# 0  Article 1\nSubject matter\n\n1. The purpose of...   json
# 1  Article 2\nScope\n\n1. This Regulation applies...   json
# 2  3. This Regulation does not apply to areas out...   json
# 3  5. This Regulation shall not affect the applic...   json
# 4  11. This Regulation does not preclude the Unio...   json
#
#                            chunk_id
# 0  542f562d7b814d409a25e8728c0abc58
# 1  ac309310e1c747b3a58f998baf718665
# 2  0507410e83cb4df198d695b439c8857c
# 3  4ecd5a1b2eb541bf836eba7910a795d4
# 4  305f8c1952b34f9cad6217d3592a6640

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
regenerate = True

if regenerate:
    required_columns = ["chapter", "article", "paragraph"]
    for col in required_columns:
        if col not in df.columns:
            df[col] = "Unknown"  

    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)

    dfg1.to_csv(outputdirectory / "graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory / "chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory / "graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4  

#print(dfg1.shape)
#dfg1.head()
# Out:
# 🔹 Processing 150 structured sections in df2Graph...
# Here's the output in JSON format based on the provided legal document context:
#
# [
#   {
#     "node_1": "Article 1",
#     "node_2": "Purpose of Regulation",
#     "edge": "describes"
#   },
#   {
#     "node_1": "Union",
#     "node_2": "Harmonised Rules",
#     "edge": "apply to"
#   },
#   {
#     "node_1": "Article 1",
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 10
#       7     if col not in df.columns:
#       8         df[col] = "Unknown"
# ---> 10 concepts_list = df2Graph(df, model='zephyr:latest')
#      11 dfg1 = graph2Df(concepts_list)
#      13 if not os.path.exists(outputdirectory):
#
# File g:\DIPLOMATIKI\KG_code\knowledge_graph-main\helpers\df_helpers.py:61, in df2Graph(dataframe, model)
#      56 for index, row in dataframe.iterrows():
#      57     #print(f"⚡ Processing Row {index + 1}/{len(dataframe)}")
#      58
#      59     # Convert row to JSON format for graphPrompt
#      60     json_input = row.to_dict()  # ✅ Use full structured JSON
# ---> 61     response = graphPrompt(json.dumps(json_input), {"chunk_id": row.get("chunk_id", index)}, model)
#      63     if response:
#      64         results.append(response)
#
# File g:\DIPLOMATIKI\KG_code\knowledge_graph-main\helpers\prompts.py:155, in graphPrompt(input_json, metadata, model)
#      91 SYS_PROMPT = (
#      92     "You are a network graph maker who extracts legal concepts and their relationships from structured legal documents. "
#      93     "You are an expert in analyzing structured documents and extracting key concepts and their relationships. "
#    (...)
#     147     "]\n\n"
#     148 )
#     153 USER_PROMPT = f"Legal Document Context:\n{input_json}\n\nExtract relationships and return a JSON array:"
# --> 155 response, _ = client.generate(model_name=model, system=SYS_PROMPT, prompt=USER_PROMPT)
#     157 try:
#     158     result = json.loads(response)
#
# File g:\DIPLOMATIKI\KG_code\knowledge_graph-main\ollama\client.py:35, in generate(model_name, prompt, system, template, context, options, callback)
#      32 full_response = ""
#      34 # Iterating over the response line by line and displaying the details
# ---> 35 for line in response.iter_lines():
#      36     if line:
#      37         # Parsing each line (JSON chunk) and extracting the details
#      38         chunk = json.loads(line)
#
# File c:\Users\BillyS\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\models.py:869, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     860 """Iterates over the response data, one line at a time.  When
#     861 stream=True is set on the request, this avoids reading the
#     862 content at once into memory for large responses.
#     863
#     864 .. note:: This method is not reentrant safe.
#     865 """
#     867 pending = None
# --> 869 for chunk in self.iter_content(
#     870     chunk_size=chunk_size, decode_unicode=decode_unicode
#     871 ):
#     872     if pending is not None:
#     873         chunk = pending + chunk
#
# File c:\Users\BillyS\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\BillyS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1041 """
#    1042 A generator wrapper for the read() method. A call will block until
#    1043 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1054     'content-encoding' header.
#    1055 """
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File c:\Users\BillyS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\response.py:1206, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1203     amt = None
#    1205 while True:
# -> 1206     self._update_chunk_length()
#    1207     if self.chunk_left == 0:
#    1208         break
#
# File c:\Users\BillyS\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\response.py:1125, in HTTPResponse._update_chunk_length(self)
#    1123 if self.chunk_left is not None:
#    1124     return None
# -> 1125 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1126 line = line.split(b";", 1)[0]
#    1127 try:
#
# File c:\Users\BillyS\AppData\Local\Programs\Python\Python312\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                                                  node_1  \
# 6644  voluntary model terms for contracts between pr...
# 6647  where the commission considers the authorisati...
# 6650  where the commission considers the authorisati...
# 6662                            widespread infringement
# 6665         work of a group referred to in paragraph 1
#
#                                                  node_2  \
# 6644                    provider of high-risk ai system
# 6647  5. where, within 15 calendar days of receipt o...
# 6650  commission shall address its decision to the m...
# 6662                                               harm
# 6665  appropriate coordination and cooperation betwe...
#
#                                                chunk_id  count  \
# 6644  b1fe88c109f84dbea1e2213d0e2a42e3,b1fe88c109f84...      2
# 6647  ed3d08d74f514936887ff9b0edaa10ff,ed3d08d74f514...      3
# 6650  ed3d08d74f514936887ff9b0edaa10ff,ed3d08d74f514...      2
# 6662  dd83a85a970b49e3824afb78f46e5523,dd83a85a970b4...      2
# 6665  37e6e9d2512a402db5a5763996294241,37e6e9d2512a4...      5
#
#                       edge
# 6644  contextual proximity
# 6647  contextual proximity
# 6650  contextual proximity
# 6662  contextual proximity
# 6665  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                                                  node_1  \
# 0             (a component of a product or of a system)
# 1             (a component of a product or of a system)
# 2                                                   (a)
# 3                                                   (a)
# 4                                                   (a)
# ...                                                 ...
# 2912  where the commission considers the authorisati...
# 2913  where the commission considers the authorisati...
# 2914                            widespread infringement
# 2915                            widespread infringement
# 2916         work of a group referred to in paragraph 1
#
#                                                  node_2  \
# 0                                          an ai system
# 1            an ai system or a general-purpose ai model
# 2                                                   (b)
# 3                                                   (c)
# 4                                                   (d)
# ...                                                 ...
# 2912  authorisation shall be withdrawn by the market...
# 2913  commission shall address its decision to the m...
# 2914                                               harm
# 2915   union law protecting the interest of individuals
# 2916  appropriate coordination and cooperation betwe...
#
#                                                chunk_id                  edge  \
# 0     e2471fe4b8c34d4da50c94b6f7cf2560,e2471fe4b8c34...  contextual proximity
# 1     e2471fe4b8c34d4da50c94b6f7cf2560,e2471fe4b8c34...  contextual proximity
# 2     b2218fd6411f435eaf18bf3725ef3624,b2218fd6411f4...  contextual proximity
# 3     b2218fd6411f435eaf18bf3725ef3624,b2218fd6411f4...  contextual proximity
# 4     b2218fd6411f435eaf18bf3725ef3624,b2218fd6411f4...  contextual proximity
# ...                                                 ...                   ...
# 2912                   ed3d08d74f514936887ff9b0edaa10ff       is withdrawn by
# 2913  ed3d08d74f514936887ff9b0edaa10ff,ed3d08d74f514...  contextual proximity
# 2914  dd83a85a970b49e3824afb78f46e5523,dd83a85a970b4...  contextual proximity
# 2915                   dd83a85a970b49e3824afb78f46e5523        is contrary to
# 2916  37e6e9d2512a402db5a5763996294241,37e6e9d2512a4...  contextual proximity
#
#       count
# 0         3
# 1         2
# 2         2
# 3         2
# 4         2
# ...     ...
# 2912      4
# 2913      2
# 2914      2
# 2915      4
# 2916      5
#
# [2917 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (612,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  31
# [['(a component of a product or of a system)', '(a)', '(a) a strategy for regulatory compliance', '(b)', '(c)', '(d)', '(provider, product manufacturer, deployer, authorised representative, importer or distributor)', '5. where, within 15 calendar days of receipt of the notification referred to in paragraph 3, objections are raised by a member state against an authorisation issued by a market surveillance authority of another member state', 'acceptable residual risk', 'accessibility requirements', 'acting contrary to its obligations pursuant to this regulation', 'adverse legal effect on a person', 'affected persons', 'ai models released under free and open licence', 'ai office', 'ai office and national competent authorities', 'ai office or national competent authorities', 'ai regulatory sandbox', 'ai system', 'ai system for which the provider has concluded that it is not high-risk according to article 6(3)', 'ai system no longer meets requirements set out in section 2', 'ai systems covered by annex i', 'ai systems covered by annex iii', 'ai systems covered by those certificates', 'ai systems that fall under the scope of annex iii but do not pose a significant risk of harm to the health, safety or fundamental rights of natural persons', 'ai-generated content', 'all information and documentation necessary to demonstrate compliance with obligations in this chapter', 'all obligations referred to in articles 53 and, where applicable, article 55', 'all the following conditions', 'amendments to annex iii', 'an ai system', 'an ai system or a general-purpose ai model', 'annex iii', 'annex iv', 'annex v', 'annex vi', 'annex xi', 'annexes vi and vii', 'annexes xi and xii', 'anomalies, dysfunctions and unexpected performance', 'another notified body', 'appeal procedure against decisions of notified bodies', 'applicable accessibility requirements', 'appropriate conformity assessment procedure', 'appropriate coordination and cooperation between notified bodies', 'appropriate liability insurance for their conformity assessment activities', 'appropriate measures to detect, prevent and mitigate possible biases identified according to point (f)', 'appropriate safeguards for fundamental rights and freedoms of natural persons', 'approval of codes of practice', 'article 11', 'article 12(1)', 'article 13', 'article 34', 'article 35 of regulation (eu) 2016/679', 'article 36', 'article 38', 'article 39', 'article 43', 'article 46', 'article 47', 'article 56', 'article 6', 'article 7', 'article 78', 'article 79(1)', 'article 9(1) of regulation (eu) 2016/679, article 10 of directive (eu) 2016/680 and article 10(1) of regulation (eu) 2018/1725', 'assessing ai systems', 'assessment and monitoring referred to in paragraph 1', 'assessment of impact on certificates issued by the notified body', 'assessment of the availability, quantity and suitability of the data sets', 'assessment under paragraph 6 of this article', 'assessment, designation and notification of conformity assessment bodies', 'assumptions', 'authorisation', 'authorisation issued pursuant to paragraph 1', 'authorisation referred to in paragraph 1', 'authorisation shall be withdrawn by the market surveillance authority of the member state concerned', 'authorised persons with appropriate confidentiality obligations', 'authorised representative', 'authorised representatives', 'authorised representatives established in the union', 'automatically generated logs of the high-risk ai system', 'bias detection and correction', 'board', 'capabilities and limitations of the general-purpose ai model', 'capturing of biometric data', 'ce marking', 'certain criminal offences referred to in point (h)(iii) of paragraph 1, point (h)', 'certificate', 'certificate issued', 'certificates', 'certificates issued by notified bodies in accordance with annex vii', 'certificates issued by the notified body', 'changes to notifications (other than extensions of scope)', 'chapter iv', 'chapter iv of this regulation', 'class ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                                   node    color  group
# 0            (a component of a product or of a system)  #57addb      1
# 1                                                  (a)  #57addb      1
# 2             (a) a strategy for regulatory compliance  #57addb      1
# 3                                                  (b)  #57addb      1
# 4                                                  (c)  #57addb      1
# ..                                                 ...      ...    ...
# 607           national market surveillance authorities  #db57cf     29
# 608  obligation to put in place a quality managemen...  #db5782     30
# 609  providers that are financial institutions subj...  #db5782     30
# 610                             participating provider  #5760db     31
# 611                                       sandbox plan  #5760db     31
#
# [612 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
